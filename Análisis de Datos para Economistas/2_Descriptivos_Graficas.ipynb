# %% [markdown]
# #### Estadíticas Descriptivas

# %% [markdown]
# ##### 1 Visualización de extremos de la base de datos

# %%
# Descriptivos estadisticos
import pandas as pd # Libreria para manejo de datos
import numpy as np # Libreria para manejo de arreglos tablas y matrices
import matplotlib.pyplot as plt # Libreria para graficar
import seaborn as sns # Libreria para graficar series de tiempo

# Cargar datos
data = pd.read_csv('BostonHousing.csv')
data2 = pd.read_csv('BankChurners.csv')

# Visualizar los primeros registros/obasvaciones
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV  CAT. MEDV
# 0   4.98  24.0          0
# 1   9.14  21.6          0
# 2   4.03  34.7          1
# 3   2.94  33.4          1
# 4   5.33  36.2          1

# %%
# Visualizar los ultimos registros/obasvaciones
data.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#      LSTAT  MEDV  CAT. MEDV
# 501   9.67  22.4          0
# 502   9.08  20.6          0
# 503   5.64  23.9          0
# 504   6.48  22.0          0
# 505   7.88  11.9          0

# %% [markdown]
# ##### 2 Conteno de valores nulos

# %%
# Valores nulos o faltantes
data.isnull().sum()
# Out:
# CRIM         0
# ZN           0
# INDUS        0
# CHAS         0
# NOX          0
# RM           0
# AGE          0
# DIS          0
# RAD          0
# TAX          0
# PTRATIO      0
# LSTAT        0
# MEDV         0
# CAT. MEDV    0
# dtype: int64

# %% [markdown]
# ##### 3 Tabla de estadísticos descriptivos

# %%
# Estadisticos descriptivos de toda la base con solo dos decimales
data.describe().round(2)
data2.describe().round(2)
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04      10127.00         10127.00        10127.00
# mean   7.391776e+08         46.33             2.35           35.93
# std    3.690378e+07          8.02             1.30            7.99
# min    7.080821e+08         26.00             0.00           13.00
# 25%    7.130368e+08         41.00             1.00           31.00
# 50%    7.179264e+08         46.00             2.00           36.00
# 75%    7.731435e+08         52.00             3.00           40.00
# max    8.283431e+08         73.00             5.00           56.00
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count                  10127.00                10127.00
# mean                       3.81                    2.34
# std                        1.55                    1.01
# min                        1.00                    0.00
# 25%                        3.00                    2.00
# ...

# %% [markdown]
# ##### 4 Estadísticos particulares una o varias variables

# %%
# Estadisticos descriptivos de una columna/variable
data2['Credit_Limit'].describe().round(2)

# Estadisticos descriptivos particulares de una columna/variable
data[['CRIM', 'MEDV']].mean().round(2)
data['CRIM'].median()
data['CRIM'].mode()
data['CRIM'].std()
data['CRIM'].var()
data['CRIM'].quantile(0.25)
data['CRIM'].quantile(0.75)
# Out:
# np.float64(3.6770825)

# %% [markdown]
# ##### 5 Filtrado, conteo y promedio dentro de cada variable

# %%
# Filtrar los datos donde el género es 'F'
datos_f = data2[data2['Gender'] == 'F']

# Calcular la edad promedio
edad_promedio = datos_f['Customer_Age'].mean().round(2)

# Mostrar la edad promedio
print(f'Edad promedio de los clientes con género F: {edad_promedio}')
# Out:
# Edad promedio de los clientes con género F: 46.46

# %% [markdown]
# ##### 6 Tablas: frecuencias, correlación y cruzadas

# %%
# Convertir la columna a tipo categórico
# Transformar variable Education_Level a categórica
data2['Education_Level'] = data2['Education_Level'].astype('category')
data2['Education_Level'] = pd.Categorical(data2['Education_Level'], categories=['Uneducated', 'High School', 'College', 'Graduate', 'Post-Graduate', 'Doctorate'], ordered=True)

# Tabla de frecuencias de una variable ordenadas
data2['Education_Level'].value_counts().sort_index()
data2['Marital_Status'].value_counts().sort_index()

# Tabla de frecuencias relativas (porcentaje) de una variable 
data2['Education_Level'].value_counts(normalize=True).sort_index().round(2)
data2['Marital_Status'].value_counts(normalize=True).round(2)
# Out:
# Marital_Status
# Married     0.46
# Single      0.39
# Unknown     0.07
# Divorced    0.07
# Name: proportion, dtype: float64

# %%
# Tabla cruzada de dos variables
pd.crosstab(data2['Education_Level'], data2['Marital_Status'])

# Tabla cruzada de dos variables con porcentajes
tabla1= pd.crosstab(data2['Education_Level'], data2['Marital_Status'], normalize='columns').round(2)
print(tabla1)

tabla2= pd.crosstab(data2['Education_Level'], data2['Marital_Status'], normalize='index').round(2)
print(tabla2)
# Out:
# Marital_Status   Divorced  Married  Single  Unknown
# Education_Level
# Uneducated           0.21     0.16    0.18     0.17
# High School          0.20     0.24    0.24     0.24
# College              0.13     0.12    0.12     0.12
# Graduate             0.35     0.37    0.36     0.36
# Post-Graduate        0.06     0.06    0.06     0.07
# Doctorate            0.06     0.05    0.05     0.04
# Marital_Status   Divorced  Married  Single  Unknown
# Education_Level
# Uneducated           0.09     0.44    0.39     0.07
# High School          0.06     0.47    0.39     0.08
# College              0.08     0.46    0.38     0.07
# Graduate             0.07     0.47    0.38     0.07
# Post-Graduate        0.08     0.47    0.37     0.08
# Doctorate            0.08     0.45    0.40     0.06

# %% [markdown]
# ##### 7 Matriz de correlación

# %%
# Tabla de correlaciones entre variables
data.corr().round(2)

# Convertir columnas categóricas a numéricas
data2_encoded = data2.copy()
data2_encoded['Education_Level'] = data2_encoded['Education_Level'].astype('category').cat.codes
data2_encoded['Marital_Status'] = data2_encoded['Marital_Status'].astype('category').cat.codes

# Tabla de correlaciones entre variables especificas 
data2_encoded[['Education_Level', 'Marital_Status']].corr().round(2)
# Out:
#                  Education_Level  Marital_Status
# Education_Level             1.00           -0.01
# Marital_Status             -0.01            1.00

# %% [markdown]
# ##### 8 Gráficas

# %% [markdown]
# ###### 8.1 Gráfica circular/Pie

# %%
# Gráfica de pastel de una variable
data2['Education_Level'].value_counts().plot(kind='pie')
# Agregar porcentaje a la gráfica
data2['Education_Level'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Cambiar colores de la gráfica
data2['Education_Level'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['red', 'blue', 'green', 'yellow', 'orange', 'purple', 'pink'])
#Colores monocromaticos cambie por intensidad
data2['Education_Level'].value_counts().plot(kind='pie', autopct='%1.1f%%', cmap='Blues')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ###### 8.2 Gráfica de Barras/Histograma

# %%
# Gráfica de barras de una variable
data2['Education_Level'].value_counts().plot(kind='bar')
# Gráfica de barras de una variable ordenada
data2['Education_Level'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Education_Level'>

# %%
# Gráfica de barras por porcentaje ordenada
data2['Education_Level'].value_counts(normalize=True).sort_index().plot(kind='bar', ylim=(0, 1))
# Out:
# <Axes: xlabel='Education_Level'>

# %%
# Cambiar a horizontal
data2['Marital_Status'].value_counts().plot(kind='barh')

# Gráfica de barras de dos variables
pd.crosstab(data2['Education_Level'], data2['Marital_Status']).plot(kind='bar')
# Out:
# <Axes: xlabel='Education_Level'>

# %% [markdown]
# ###### 8.3 Dispersión

# %%
# Gráfica de dispersión de dos variables
plt.scatter(data['CRIM'], data['MEDV'])

# Agregar nombres a los ejes
plt.xlabel('Tasa de criminalidad (CRIM)')  # Nombre del eje X
plt.ylabel('Valor mediano de viviendas (MEDV)')  # Nombre del eje Y
# Agregar titulo al gráfico
plt.title('Gráfico de dispersión de CRIM vs MEDV')  # Título del gráfico

# Agregar linea de tendencia
sns.regplot(x='CRIM', y='MEDV', data=data)
# Agregar ecuación de la linea de tendencia
plt.text(10, 40, 'y = 24.0331 - 0.4152x', fontsize=12)
# Linea de tencia no pase del 0 en los ejes
plt.ylim(0, 60)

# Cambiar tamaño de puntos
plt.scatter(data['CRIM'], data['MEDV'], s=100)
# Cambiar color de puntos
plt.scatter(data['CRIM'], data['MEDV'], c='red')

# %% [markdown]
# ###### 8.4 Diagrama de caja

# %%
# Diagrama de caja de una variable
data['MEDV'].plot(kind='box')

# Diagrama de caja de dos variables
data[['CRIM', 'MEDV']].plot(kind='box')

# Diagrama de caja de dos variables con colores
data[['CRIM', 'MEDV']].plot(kind='box', color=dict(boxes='red', whiskers='blue', medians='green', caps='black'))
# Out:
# <Axes: >

# %% [markdown]
# ###### 8.5 Mapa de correlación

# %%
# tabla de correlaciones
data.corr()

#Correlación de dos variables
data['CRIM'].corr(data['MEDV'])

# Tabla de correlaciones de dos variables
data[['CRIM', 'MEDV']].corr()
# Out:
#           CRIM      MEDV
# CRIM  1.000000 -0.388305
# MEDV -0.388305  1.000000

# %%
# Mapa de correlaciones
numeric_data = data.select_dtypes(include=[np.number])
sns.heatmap(numeric_data.corr(), annot=True)
# Cambiar tamaño de los numeros de la correlación
# Out:
# <Axes: >

# %%
# Cambiar los colores del mapa de correlaciones
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', fmt='.1f')
# Out:
# <Axes: >

# %% [markdown]
# ###### 8.6 Series de tiempo

# %%
# Guardar archivo excel en datos3
data3 = pd.read_excel('Empleo_mujeres.xlsx')

# Gráfica de serie de tiempo
data3.plot(x='Periodos', y='Mujeres', kind='line')

# Agregar etiquetas a los ejes y título al gráfico
plt.xlabel('Periodos')  # Nombre del eje X
plt.ylabel('Tasa (%)')  # Nombre del eje Y
plt.title('Tasa de empleo femenino 2007-2024')  # Título del gráfico

# Mover el periodo a la parte inferior
plt.xticks(rotation=45)
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.,  70.,  80.]),
#  [Text(-10.0, 0, '2022/01'),
#   Text(0.0, 0, '2007/01'),
#   Text(10.0, 0, '2009/03'),
#   Text(20.0, 0, '2012/01'),
#   Text(30.0, 0, '2014/03'),
#   Text(40.0, 0, '2017/01'),
#   Text(50.0, 0, '2019/03'),
#   Text(60.0, 0, '2022/01'),
#   Text(70.0, 0, ''),
#   Text(80.0, 0, '')])

# %%
# Instalamos lo necesario para descomponer una serie de tiempo
# %pip install statsmodels
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Descomposición de la serie de tiempo
result = seasonal_decompose(data3['Mujeres'], model='multiplicative', period=1)

# Gráfica de la serie de tiempo
result.plot()
plt.show()

# %% [markdown]
# ###### 8.7 Ranking de variables

# %%
soccer=pd.read_csv('Soccer_Football Clubs Ranking.csv')
soccer.info()
soccer.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2812 entries, 0 to 2811
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ranking                2812 non-null   int64
#  1   club name              2812 non-null   object
#  2   country                2812 non-null   object
#  3   point score            2812 non-null   int64
#  4   1 year change          2812 non-null   int64
#  5   previous point scored  2812 non-null   int64
#  6   symbol change          2812 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 153.9+ KB
#    ranking                club name    country  point score  1 year change  \
# 0       88                1. FC Köln   Germany         1633            105
# 1       74        1. FC Union Berlin   Germany         1655              5
# 2      780  12 de Octubre de Itaugua  Paraguay         1377             70
# ...

# %%
df_sorted=soccer.sort_values("ranking")
df_sorted.head()
# Out:
#       ranking       club name   country  point score  1 year change  \
# 384         1   Bayern München  Germany         2045              0
# 1572        2     Liverpool FC  England         2043             12
# 1637        3  Manchester City  England         2010              1
# 2137        4      Real Madrid    Spain         1957              1
# 584         5       Chelsea FC  England         1939              4
#
#       previous point scored symbol change
# 384                    2057             -
# 1572                   1840             +
# 1637                   2049             -
# 2137                   1949             +
# 584                    1861             +

# %%
# Tomar los 10 primeros y 10 últimos
top_10 = df_sorted.head(10)
bottom_10 = df_sorted.tail(10)

# Junta los 10 primeros y 10 últimos
top_bottom_10 = pd.concat([top_10, bottom_10])




# Cambiar palete de colores
plt.barh(top_10['club name '], top_10['point score'], color=sns.color_palette('viridis', 10))

plt.xlabel('Ranking')
plt.title('Top 10 Clubs')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# ###### 8.8 Dispersión con etiquetas (Grupos)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos
df = pd.read_csv("Utilities.csv")

# Crear el gráfico de dispersión
plt.figure(figsize=(8, 6))
plt.scatter(df['Sales'], df['Fuel_Cost'], alpha=0.7)

# Agregar etiquetas a los puntos
for i, txt in enumerate(df['Company']):
    plt.text(df['Sales'][i], df['Fuel_Cost'][i], txt, fontsize=8, rotation=20, verticalalignment='bottom')

# Configurar etiquetas y límites
plt.xlabel("Sales")
plt.ylabel("Fuel Cost")
plt.xlim(2000, 20000)
plt.title("Fuel Cost vs Sales")
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ###### 8.9 Map Chart: Visualización de datos geoespaciales

# %%
import geopandas as gpd
import folium 
from folium.plugins import HeatMap

# Cargar el archivo geográfico de México (GeoJSON o Shapefile)
# Asegúrate de tener la ruta correcta al archivo
mapa_mexico = gpd.read_file("states.geojson")
mapa_mexico.head()

#ordemanos los estados por la columna state_name
mapa_mexico = mapa_mexico.sort_values(by='state_name')
mapa_mexico.head()
# Out:
#       id  state_code           state_name  \
# 19  None           1       Aguascalientes
# 5   None           2      Baja California
# 7   None           3  Baja California Sur
# 30  None           4             Campeche
# 15  None           7              Chiapas
#
#                                              geometry
# 19  POLYGON ((-102.2533 22.37458, -102.18896 22.36...
# 5   MULTIPOLYGON (((-115.2138 28.37512, -115.16752...
# 7   MULTIPOLYGON (((-109.80049 24.15197, -109.8020...
# 30  POLYGON ((-90.38193 20.7496, -90.38193 20.7470...
# 15  POLYGON ((-91.81435 17.90028, -91.77948 17.849...

# %%
accidentes = pd.read_excel('ATUS_1.xlsx')
accidentes.head(20)
# Quitamos las observaciones de la cero a la 5
accidentes = accidentes[6:38]
accidentes.head(33)
#Eliminamos la primer columna
accidentes = accidentes.drop(accidentes.columns[0], axis=1)
accidentes.head(33)
#Renombramos las columnas
accidentes.columns = ['Estado', 'Accidentes']
#Reiniciamos el index
accidentes = accidentes.reset_index(drop=True)
accidentes.head(33)
# Out:
#                              Estado  Accidentes
# 0                    Aguascalientes      4473.0
# 1                   Baja California     11782.0
# 2               Baja California Sur      6045.0
# 3                          Campeche      4574.0
# 4              Coahuila de Zaragoza     10876.0
# 5                            Colima      6225.0
# 6                           Chiapas      4065.0
# 7                         Chihuahua     26559.0
# 8                  Ciudad de México      7276.0
# 9                           Durango     11631.0
# 10                       Guanajuato     17703.0
# 11                         Guerrero      7414.0
# 12                          Hidalgo      4593.0
# 13                          Jalisco     14293.0
# 14                           México     21105.0
# 15              Michoacán de Ocampo     16196.0
# 16                          Morelos      8864.0
# 17                          Nayarit      2852.0
# 18                       Nuevo León     80582.0
# ...

# %%
# Unir la base de accidentes con el mapa de México
# Asegúrate de que la columna "Estado" en ambos DataFrames sea la misma
mexico = mapa_mexico.merge(accidentes, left_on="state_name", right_on="Estado")
mexico.head()

# Crear un mapa centrado en México
m = folium.Map(location=[23.6345, -102.5528], zoom_start=5)

# Opción 2: Crear un mapa coroplético (coloreado por estado)
folium.Choropleth(
    geo_data=mexico,  # Datos geográficos
    name="Accidentes por estado",
    data=mexico,      # Datos numéricos
    columns=["Estado", "Accidentes"],  # Columnas para el valor
    key_on="feature.properties.state_name",  # Clave para unir los datos
    fill_color="YlOrRd",  # Escala de colores
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Número de accidentes"
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
